# %%
#how to read and show an image in python
import cv2
import matplotlib.pyplot as plt
img =cv2.imread('image1.jpeg')
plt.imshow(img)
plt.show()

# %%
#Read RGB image
img3=cv2.imread('rahul.jpg')
img3=cv2.cvtColor(img3,cv2.COLOR_RGB2BGR)
plt.imshow(img3)
plt.show()

# %%
#How to show multiple images in on figure
import cv2
from matplotlib import pyplot as plt
fig=plt.figure(figsize=(10,7))
rows=2
columns=2
Image1=cv2.imread('image1.jpeg')
Image2=cv2.imread('image2.jpeg')
Image3=cv2.imread('rahul.jpg')
Image4=cv2.imread('rahul1.jpg')
fig.add_subplot(rows,columns,1)
plt.imshow(Image1)
plt.axis('off')
plt.title("First")

fig.add_subplot(rows,columns,2)
plt.imshow(Image2)
plt.axis('off')
plt.title("second")
fig.add_subplot(rows,columns,3)
plt.imshow(Image3)
plt.axis('off')
plt.title('Third')
fig.add_subplot(rows,columns,4)
plt.imshow(Image4)
plt.axis('off')
plt.title("Fourth")
# Out:
# Text(0.5, 1.0, 'Fourth')

# %%
#Red an image and convert it to Binary image
import cv2
img=cv2.imread('rahul.jpg',2)
ret, bw_img=cv2.threshold(img,127,255,cv2.THRESH_BINARY)
bw=cv2.threshold(img, 127,255,cv2.THRESH_BINARY)
cv2.imshow("Binary", bw_img)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
#Red an RGB image and convert it to Gray image
import cv2
image = cv2.imread('rahul.jpg')
# cv2.imshow('Original', image)
# cv2.waitKey(0)
gray_image = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)
cv2.imshow('Grayscale', gray_image)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
#write a program to generate mirror image flip horizonatlly and flip vertically using loop in python

import cv2
import numpy as np
from matplotlib import pyplot as plt
img_orginal=cv2.imread('image5.jpg')
img=cv2.cvtColor(img_orginal, cv2.COLOR_BGR2RGB)
x,y,z=np.shape(img)
mirror_img=np.zeros((x,y,z),dtype=int)
for i in range(0,x):
    k=0
    for j in range(y-1,0,-1):
        mirror_img[i][k][0]=img[i][j][0]
        mirror_img[i][k][1]=img[i][j][1]
        mirror_img[i][k][2]=img[i][j][2]
        k=k+1
        
    cv2.imwrite('image2.jpeg',mirror_img)
    plt.subplot(1,2,1)
    plt.title('Orginal Image')
    plt.imshow(img)
    plt.subplot(1,2,2)
    plt.title('Mirror_img')
    plt.imshow(mirror_img)

# %%
#write a python program to find the complement of an image
import cv2
from matplotlib import pyplot as plt
img=cv2.imread('image1.jpeg')
comp_image=255-img
plt.subplot(1,2,1)
plt.title('Orginal Image')
plt.imshow(img)
plt.subplot(1,2,2)
plt.title('Complementary image')
plt.imshow(comp_image)

# %%
#write a python program to resize an image
from PIL import Image
im=Image.open('image4.jpg')
width,height = im.size
left=4
top=height/5
right=154
bottom=3*height/5
im1=im.crop((left,top,right,bottom))
newsize=(300,300)
im1= im1.resize(newsize)
im1.show()
# Out:
# (eog:15433): Gtk-WARNING **: 23:24:48.675: Theme file for macOSBigSur has no directories

# %%
#write a python program to rotate an image
from PIL import Image
from matplotlib import pyplot as plt
Orginal_image=Image.open('image5.jpg')
rotated_image1=Orginal_image.rotate(60)
plt.subplot(1,2,1)
plt.title('Orginal Image')
plt.imshow(Orginal_image)
plt.subplot(1,2,2)
plt.title('Roated image')
plt.imshow(rotated_image1)

# %%
#write a python code to show the Red Green Blue components of an RGB image separetly
import cv2
import numpy as np
from matplotlib import pyplot as plt
rgb_img = cv2.imread('image5.jpg')
x,y,z = np.shape(rgb_img)
red = np.zeros((x,y,z),dtype=int)
green = np.zeros((x,y,z),dtype=int)
blue = np.zeros((x,y,z),dtype=int)
for i in range(0,x):
    for j in range(0,y):
        red[i][j][0] = rgb_img[i][j][0]
        green[i][j][1]= rgb_img[i][j][1]
        blue[i][j][2] = rgb_img[i][j][2]
img= cv2.cvtColor(rgb_img, cv2.COLOR_RGB2BGR)
plt.subplot(2,2,1)
plt.title('original image')
plt.imshow(img)
plt.axis('off')
plt.subplot(2,2,2)
plt.title('Red')
plt.imshow(red)
plt.axis('off')
plt.subplot(2,2,3)
plt.title('Green')
plt.imshow(green)
plt.axis('off')
plt.subplot(2,2,4)
plt.title('Blue')
plt.imshow(blue)
plt.axis('off')
# Out:
# (-0.5, 999.5, 665.5, -0.5)
